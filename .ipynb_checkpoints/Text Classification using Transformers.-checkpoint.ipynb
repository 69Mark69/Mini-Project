# %%
'''
import numpy as np
import matplotlib.pyplot as plt
def PositionalEncodings(seq_len,d,n=1000):
    P = np.zeros((seq_len,d))
    for k in range(seq_len):
        for i in np.arange(int(d/2)):
            Denominator = np.power(n,2*i/d)
            P[k,2*i]=np.sin(k/Denominator)
            P[k,2*i+1]=np.cos(k/Denominator)
    return P

P = PositionalEncodings(seq_len = 4,d=4,n=100)
'''
# Out:
# '\nimport numpy as np\nimport matplotlib.pyplot as plt\ndef PositionalEncodings(seq_len,d,n=1000):\n    P = np.zeros((seq_len,d))\n    for k in range(seq_len):\n        for i in np.arange(int(d/2)):\n            Denominator = np.power(n,2*i/d)\n            P[k,2*i]=np.sin(k/Denominator)\n            P[k,2*i+1]=np.cos(k/Denominator)\n    return P\n\nP = PositionalEncodings(seq_len = 4,d=4,n=100)\n'

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import MultiHeadAttention , LayerNormalization , Dropout , Layer
from tensorflow.keras.layers import Embedding , Input , GlobalAveragePooling1D , Dense
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential , Model
import numpy as np
import warnings
warnings.filterwarnings("ignore",category=np.VisibleDeprecationWarning)
import matplotlib.pyplot as plt

# %%
class TransformerBlock(Layer):
    def __init__(self,embed_dim,num_heads,ff_dim,rate=0.1):
        super(TransformerBlock,self).__init__()
        self.att= MultiHeadAttention(num_heads=num_heads,key_dim = embed_dim)
        self.ffn=Sequential([Dense(ff_dim,activation="relu"),
                            Dense(embed_dim),]
        )
        self.layernorm1=LayerNormalization(epsilon=1e-6)
        self.layernorm2=LayerNormalization(epsilon=1e-6)
        self.dropout1=Dropout(rate)
        self.dropout2=Dropout(rate)
        
    def call(self,inputs,training):
        attn_output = self.att(inputs,inputs)
        attn_output=self.dropout1(attn_output,training=training)
        out1=self.layernorm1(inputs+attn_output)
        ffn_output=self.ffn(out1)
        ffn_output=self.dropout2(ffn_output,training=training)
        return self.layernorm2(out1+ffn_output)

# %%
class TokenAndPositionEmbedding(Layer):
    def __init__(self,maxlen,vocab_size,embed_dim):
        super(TokenAndPositionEmbedding,self).__init__()
        self.token_emb=Embedding(input_dim=vocab_size,output_dim=embed_dim)
        self.pos_emb=Embedding(input_dim=maxlen,output_dim=embed_dim)
        
    def call(self,x):
        maxlen=tf.shape(x)[-1]
        positions=tf.range(start=0,limit=maxlen,delta=1)
        positions=self.pos_emb(positions)
        x=self.token_emb(x)
        return x + positions

# %%
vocab_size=20000
maxlen=200

(x_train,y_train),(x_val,y_val)=imdb.load_data(num_words=vocab_size)
print(len(x_train),"Training Sequences")
print(len(x_val),"Validation Sequences")
# Out:
# 25000 Training Sequences
# 25000 Validation Sequences

# %%
plt.plot(x_train)
plt.show()

# %%
x_train=tf.keras.preprocessing.sequence.pad_sequences(x_train,maxlen=maxlen)
x_val=tf.keras.preprocessing.sequence.pad_sequences(x_val,maxlen=maxlen)

# %%
embed_dim=32
num_heads=2
ff_dim=32

inputs=Input(shape=(maxlen,))
embedding_layer=TokenAndPositionEmbedding(maxlen,vocab_size,embed_dim)
x=embedding_layer(inputs)
transformer_block=TransformerBlock(embed_dim,num_heads,ff_dim)
x=transformer_block(x)
x=GlobalAveragePooling1D()(x)
x=Dropout(0.1)(x)
x=Dense(20,activation="relu")(x)
x=Dropout(0.1)(x)
outputs=Dense(2,activation="softmax")(x)

model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
history=model.fit(x_train,y_train,
                 batch_size=64,epochs=2,
                 validation_data=(x_val,y_val)
                 )
# Out:
# Epoch 1/2
# 391/391 [==============================] - 53s 129ms/step - loss: 0.4223 - accuracy: 0.7896 - val_loss: 0.2871 - val_accuracy: 0.8790
# Epoch 2/2
# 391/391 [==============================] - 49s 126ms/step - loss: 0.2080 - accuracy: 0.9219 - val_loss: 0.3866 - val_accuracy: 0.8438

# %%
model.save_weights("predict_class.h5")

# %%
results = model.evaluate(x_val,y_val,verbose=2)

for name,value in zip(model.metrics_names,results):
    print("%s: %.3f" %(name,value))
# Out:
# 782/782 - 13s - loss: 0.3866 - accuracy: 0.8438 - 13s/epoch - 17ms/step
# loss: 0.387
# accuracy: 0.844

# %%
y_val[:10]
# Out:
# array([0, 1, 1, 0, 1, 1, 1, 0, 0, 1], dtype=int64)

# %%
np.argmax(model.predict(x_val[1:2]))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1

# %%
np.argmax(model.predict(x_val[1:2]))
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1

# %%
np.argmax(model.predict(x_val[2:3]))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1

# %%
sp = 0
nsp = 0
fp = 0
fn = 0
c = []
b=[]
n = int(input("Enter number of Reviews to check : "))
for i in range(0,n):
    a = np.argmax(model.predict(x_val[i:i+1]))
    if(a==y_val[i:i+1] and a == 1):
        sp = sp+1
        print("Accurate Result : Positive Review")
        c=np.append(c,i)
    elif(a==y_val[i:i+1] and a == 0):
        nsp = nsp+1
        print("Accurate Result : Negative Review")
        b=np.append(b,i)
    else:
        if(a!=y_val[i:i+1] and a==1):
            fp = fp+1
        elif(a!=y_val[i:i+1] and a==0):
            fn = fn+1
        print("Invalid Result")
    print(a,end = ""),print("->",end=""),print(y_val[i:i+1])
print("Accuracy : ",((sp+nsp)/n)*100,"%")
print("Positive Reviews : ",sp)
print("Negative Reviews : ",nsp)
print("Invalid Reviews : ",(n-(sp+nsp)))
rating =int(sp/(n/5))
print('Rating - ',end = "")
for i in range(0,rating):
    print("*",end="")
# Out:
# Enter number of Reviews to check : 20000
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 46ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 53ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 45ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 64ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 50ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 50ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 43ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 53ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 32ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 40ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 31ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 50ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 52ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 48ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 47ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 42ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 47ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 68ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 47ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 44ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 30ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 47ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 49ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 49ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 35ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 35ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 49ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 49ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 44ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 48ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 33ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 45ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 43ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 40ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 46ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 42ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 52ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 38ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 32ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 37ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 36ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 39ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 39ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 38ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 41ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 40ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 34ms/step
# ...
# 0->[0]
# 1/1 [==============================] - 0s 80ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 80ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 56ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 56ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 61ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 55ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 53ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 64ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 56ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 55ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Invalid Result
# 1->[0]
# 1/1 [==============================] - 0s 65ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 76ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 70ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 55ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 55ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 67ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 82ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 62ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 61ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 165ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 66ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 69ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 78ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 65ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 66ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 83ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 80ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 68ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 72ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 84ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 67ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 85ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 77ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 66ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 66ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 69ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 80ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 60ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 59ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 66ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 62ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 63ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 58ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 61ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 64ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 56ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 54ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 59ms/step
# Accurate Result : Negative Review
# 0->[0]
# 1/1 [==============================] - 0s 57ms/step
# Accurate Result : Positive Review
# 1->[1]
# 1/1 [==============================] - 0s 63ms/step
# Invalid Result
# 0->[1]
# 1/1 [==============================] - 0s 62ms/step
# Invalid Result
# 0->[1]
# Accuracy :  84.52 %
# Positive Reviews :  7463
# Negative Reviews :  9441
# Invalid Reviews :  3096
# Rating - *

# %%
print(fp,fn)
# Out:
# 612 2484

# %%
cn = [[sp , fp ],
     [fn , nsp]]

cn_norm = cn/np.sum(cn)
plt.figure(figsize=(8,6))

plt.imshow(cn_norm,cmap=plt.cm.Blues)
plt.xticks([0, 1], ['Negative', 'Positive'])
plt.yticks([0, 1], ['Negative', 'Positive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.colorbar()
for i in range(cn_norm.shape[0]):
    for j in range(cn_norm.shape[1]):
        plt.text(j, i, '{:.1%}'.format(cn_norm[i, j]), ha='center', va='center')

# Remove the grid lines
plt.grid(False)
plt.title('Confusion Matrix')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Compute the AUC score
auc_score = roc_auc_score(y_test, y_prob)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc_score))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.50      0.50     12500
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#    micro avg       0.50      0.50      0.50     12500
#    macro avg       0.17      0.17      0.17     12500
# weighted avg       0.50      0.50      0.50     12500
# C:\Users\markp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\markp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\markp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\markp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\markp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\markp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
